# %% [markdown]
# ### Dataframe from file
# Pandas supports loading data from multiple file formats, including: excel, json, csv, xml

# %%
import pandas as pd

# %%
pd.read_csv("../Data/students.csv")
# Out:
#     name class            email
# 0   adam  AI23   adam@gmail.com
# 1  kalle  AI23  kalle@gmail.com
# 2    eva  AI22    eva@gmail.com

# %%
pd.read_csv("../Data/students.csv", header=None)
# Out:
#        0      1                2
# 0   name  class            email
# 1   adam   AI23   adam@gmail.com
# 2  kalle   AI23  kalle@gmail.com
# 3    eva   AI22    eva@gmail.com

# %%
pd.read_csv("../Data/students.csv", header=0)
# Out:
#     name class            email
# 0   adam  AI23   adam@gmail.com
# 1  kalle  AI23  kalle@gmail.com
# 2    eva  AI22    eva@gmail.com

# %%
students = pd.read_csv("../Data/students.csv", header=0)

# %%
students.head(1)
# Out:
#    name class           email
# 0  adam  AI23  adam@gmail.com

# %%
autos = pd.read_json("../Data/autos_json.json")

# %%
autos.head(1)
# Out:
#   aspiration   body-style  bore  city-mpg  compression-ratio  curb-weight  \
# 0        std  convertible  3.47        21                9.0         2548
#
#   drive-wheels engine-location  engine-size engine-type  ...         make  \
# 0          rwd           front          130        dohc  ...  alfa-romero
#
#   normalized-losses  num-of-cylinders  num-of-doors  peak-rpm    price stroke  \
# 0               NaN              four           two    5000.0  13495.0   2.68
#
#    symboling wheel-base width
# 0          3       88.6  64.1
#
# [1 rows x 26 columns]

# %%
scb = pd.read_excel("../Data/scb_pop.xlsx")

# %%
scb.head()
# Out:
#                           Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                NaN        NaN        NaN        NaN
# 1  Befolkningsstatistik i sammandrag        NaN        NaN        NaN
# 2                                NaN       2022       2021       2020
# 3              Folkmängd 31 december   10521556   10452326   10379295
# 4                                Män    5298324    5260707    5222847
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 1        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 2       2019       2018       2017       2016       2015       2014  ...
# 3   10327589   10230185   10120242    9995153    9851017    9747355  ...
# 4    5195814    5142438    5082662    5013347    4930966    4872240  ...
#
#   Unnamed: 37 Unnamed: 38 Unnamed: 39 Unnamed: 40  Unnamed: 41  Unnamed: 42  \
# ...

# %%
scb = pd.read_excel("../Data/scb_pop.xlsx", skiprows=3)

# %%
scb.head()
# Out:
#                                   Unnamed: 0      2022      2021      2020  \
# 0                      Folkmängd 31 december  10521556  10452326  10379295
# 1                                        Män   5298324   5260707   5222847
# 2                                    Kvinnor   5223232   5191619   5156448
# 3                     Antal personer 0-17 år   2194785   2198240   2189403
# 4  Personer 0-17 år i % av hela befolkningen      20.9        21      21.1
#
#        2019      2018      2017     2016     2015     2014  ...          1986  \
# 0  10327589  10230185  10120242  9995153  9851017  9747355  ...  8.381515e+06
# 1   5195814   5142438   5082662  5013347  4930966  4872240  ...  4.137513e+06
# 2   5131775   5087747   5037580  4981806  4920051  4875115  ...  4.244002e+06
# 3   2180508   2155379   2121598  2076407  2025077  1985282  ...  1.836443e+06
# 4      21.1      21.1        21     20.8     20.6     20.4  ...  2.191063e+01
#
# ...

# %%
scb.head().transpose()
# Out:
#                                 0          1          2  \
# Unnamed: 0  Folkmängd 31 december        Män    Kvinnor
# 2022                     10521556    5298324    5223232
# 2021                     10452326    5260707    5191619
# 2020                     10379295    5222847    5156448
# 2019                     10327589    5195814    5131775
# 2018                     10230185    5142438    5087747
# 2017                     10120242    5082662    5037580
# 2016                      9995153    5013347    4981806
# 2015                      9851017    4930966    4920051
# 2014                      9747355    4872240    4875115
# 2013                      9644864    4814357    4830507
# 2012                      9555893    4765905    4789988
# 2011                      9482855    4726834    4756021
# 2010                      9415570    4690244    4725326
# 2009                    9340682.0  4649014.0  4691668.0
# 2008                    9256347.0  4603710.0  4652637.0
# ...

# %%
autos.head()
# Out:
#   aspiration   body-style  bore  city-mpg  compression-ratio  curb-weight  \
# 0        std  convertible  3.47        21                9.0         2548
# 1        std  convertible  3.47        21                9.0         2548
# 2        std    hatchback  2.68        19                9.0         2823
# 3        std        sedan  3.19        24               10.0         2337
# 4        std        sedan  3.19        18                8.0         2824
#
#   drive-wheels engine-location  engine-size engine-type  ...         make  \
# 0          rwd           front          130        dohc  ...  alfa-romero
# 1          rwd           front          130        dohc  ...  alfa-romero
# 2          rwd           front          152        ohcv  ...  alfa-romero
# 3          fwd           front          109         ohc  ...         audi
# 4          4wd           front          136         ohc  ...         audi
#
# ...

# %%
autos.head(10)
# Out:
#   aspiration   body-style  bore  city-mpg  compression-ratio  curb-weight  \
# 0        std  convertible  3.47        21                9.0         2548
# 1        std  convertible  3.47        21                9.0         2548
# 2        std    hatchback  2.68        19                9.0         2823
# 3        std        sedan  3.19        24               10.0         2337
# 4        std        sedan  3.19        18                8.0         2824
# 5        std        sedan  3.19        19                8.5         2507
# 6        std        sedan  3.19        19                8.5         2844
# 7        std        wagon  3.19        19                8.5         2954
# 8      turbo        sedan  3.13        17                8.3         3086
# 9      turbo    hatchback  3.13        16                7.0         3053
#
#   drive-wheels engine-location  engine-size engine-type  ...         make  \
# 0          rwd           front          130        dohc  ...  alfa-romero
# ...

# %%
autos.tail()
# Out:
#     aspiration body-style  bore  city-mpg  compression-ratio  curb-weight  \
# 200        std      sedan  3.78        23                9.5         2952
# 201      turbo      sedan  3.78        19                8.7         3049
# 202        std      sedan  3.58        18                8.8         3012
# 203      turbo      sedan  3.01        26               23.0         3217
# 204      turbo      sedan  3.78        19                9.5         3062
#
#     drive-wheels engine-location  engine-size engine-type  ...   make  \
# 200          rwd           front          141         ohc  ...  volvo
# 201          rwd           front          141         ohc  ...  volvo
# 202          rwd           front          173        ohcv  ...  volvo
# 203          rwd           front          145         ohc  ...  volvo
# 204          rwd           front          141         ohc  ...  volvo
#
#     normalized-losses  num-of-cylinders  num-of-doors  peak-rpm    price  \
# ...

# %%
autos.sample()
# Out:
#    aspiration body-style  bore  city-mpg  compression-ratio  curb-weight  \
# 83      turbo  hatchback  3.59        19                7.0         2921
#
#    drive-wheels engine-location  engine-size engine-type  ...        make  \
# 83          fwd           front          156         ohc  ...  mitsubishi
#
#    normalized-losses  num-of-cylinders  num-of-doors  peak-rpm    price  \
# 83               NaN              four           two    5000.0  14869.0
#
#    stroke  symboling wheel-base width
# 83   3.86          3       95.9  66.3
#
# [1 rows x 26 columns]

# %%
autos.sample(5)
# Out:
#     aspiration body-style  bore  city-mpg  compression-ratio  curb-weight  \
# 64         std  hatchback  3.39        26                8.6         2425
# 88         std      sedan  3.17        23                7.5         2403
# 161        std  hatchback  3.19        28                9.0         2122
# 98         std    hardtop  3.15        31                9.4         2008
# 113        std      wagon  3.46        19                8.4         3285
#
#     drive-wheels engine-location  engine-size engine-type  ...        make  \
# 64           fwd           front          122         ohc  ...       mazda
# 88           fwd           front          110         ohc  ...  mitsubishi
# 161          fwd           front           98         ohc  ...      toyota
# 98           fwd           front           97         ohc  ...      nissan
# 113          rwd           front          120           l  ...      peugot
#
# ...

# %%
autos
# Out:
#     aspiration   body-style  bore  city-mpg  compression-ratio  curb-weight  \
# 0          std  convertible  3.47        21                9.0         2548
# 1          std  convertible  3.47        21                9.0         2548
# 2          std    hatchback  2.68        19                9.0         2823
# 3          std        sedan  3.19        24               10.0         2337
# 4          std        sedan  3.19        18                8.0         2824
# ..         ...          ...   ...       ...                ...          ...
# 200        std        sedan  3.78        23                9.5         2952
# 201      turbo        sedan  3.78        19                8.7         3049
# 202        std        sedan  3.58        18                8.8         3012
# 203      turbo        sedan  3.01        26               23.0         3217
# 204      turbo        sedan  3.78        19                9.5         3062
#
# ...

# %%
pd.set_option("display.max_columns", None)

# %%
pd.set_option("display.max_rows", 6)

# %%
autos
# Out:
#     aspiration   body-style  bore  city-mpg  compression-ratio  curb-weight  \
# 0          std  convertible  3.47        21                9.0         2548
# 1          std  convertible  3.47        21                9.0         2548
# 2          std    hatchback  2.68        19                9.0         2823
# ..         ...          ...   ...       ...                ...          ...
# 202        std        sedan  3.58        18                8.8         3012
# 203      turbo        sedan  3.01        26               23.0         3217
# 204      turbo        sedan  3.78        19                9.5         3062
#
#     drive-wheels engine-location  engine-size engine-type fuel-system  \
# 0            rwd           front          130        dohc        mpfi
# 1            rwd           front          130        dohc        mpfi
# 2            rwd           front          152        ohcv        mpfi
# ..           ...             ...          ...         ...         ...
# ...

# %%
autos.shape
# Out:
# (205, 26)

# %%
rows, columns = autos.shape
print(f"Dataframe has {rows} rows and {columns} columns.")
# Out:
# Dataframe has 205 rows, and 26 columns.

# %%
len(autos)
# Out:
# 205

# %%
len(autos.columns)
# Out:
# 26

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   aspiration         205 non-null    object
#  1   body-style         205 non-null    object
#  2   bore               201 non-null    float64
#  3   city-mpg           205 non-null    int64
#  4   compression-ratio  205 non-null    float64
#  5   curb-weight        205 non-null    int64
#  6   drive-wheels       205 non-null    object
#  7   engine-location    205 non-null    object
#  8   engine-size        205 non-null    int64
#  9   engine-type        205 non-null    object
#  10  fuel-system        205 non-null    object
#  11  fuel-type          205 non-null    object
#  12  height             205 non-null    float64
#  13  highway-mpg        205 non-null    int64
#  14  horsepower         203 non-null    float64
#  15  length             205 non-null    float64
# ...

# %% [markdown]
# ### Convert to common formats

# %%
# Copy DataFrame to clipboard (then use ctrl+v)
autos.to_clipboard()

# %%
csv_string = autos.to_csv()

# %%
print(csv_string[:1000])
# Out:
# ,aspiration,body-style,bore,city-mpg,compression-ratio,curb-weight,drive-wheels,engine-location,engine-size,engine-type,fuel-system,fuel-type,height,highway-mpg,horsepower,length,make,normalized-losses,num-of-cylinders,num-of-doors,peak-rpm,price,stroke,symboling,wheel-base,width
# 0,std,convertible,3.47,21,9.0,2548,rwd,front,130,dohc,mpfi,gas,48.8,27,111.0,168.8,alfa-romero,,four,two,5000.0,13495.0,2.68,3,88.6,64.1
# 1,std,convertible,3.47,21,9.0,2548,rwd,front,130,dohc,mpfi,gas,48.8,27,111.0,168.8,alfa-romero,,four,two,5000.0,16500.0,2.68,3,88.6,64.1
# 2,std,hatchback,2.68,19,9.0,2823,rwd,front,152,ohcv,mpfi,gas,52.4,26,154.0,171.2,alfa-romero,,six,two,5000.0,16500.0,3.47,1,94.5,65.5
# 3,std,sedan,3.19,24,10.0,2337,fwd,front,109,ohc,mpfi,gas,54.3,30,102.0,176.6,audi,164.0,four,four,5500.0,13950.0,3.4,2,99.8,66.2
# 4,std,sedan,3.19,18,8.0,2824,4wd,front,136,ohc,mpfi,gas,54.3,22,115.0,176.6,audi,164.0,five,four,5500.0,17450.0,3.4,2,99.4,66.4
# ...

# %%
autos.to_csv("../Data/autos.csv", index=None)

# %%
autos.to_json("../Data/new_autos.json", indent=4, orient="records")

# %%
jason_string = autos.to_json(indent=4, orient="records")
print(jason_string[:200])
# Out:
# [
#     {
#         "aspiration":"std",
#         "body-style":"convertible",
#         "bore":3.47,
#         "city-mpg":21,
#         "compression-ratio":9.0,
#         "curb-weight":2548,
#         "drive-wheels":

# %%
my_dict = autos.to_dict(orient="records")

# %%
my_dict
# Out:
# [{'aspiration': 'std',
#   'body-style': 'convertible',
#   'bore': 3.47,
#   'city-mpg': 21,
#   'compression-ratio': 9.0,
#   'curb-weight': 2548,
#   'drive-wheels': 'rwd',
#   'engine-location': 'front',
#   'engine-size': 130,
#   'engine-type': 'dohc',
#   'fuel-system': 'mpfi',
#   'fuel-type': 'gas',
#   'height': 48.8,
#   'highway-mpg': 27,
#   'horsepower': 111.0,
#   'length': 168.8,
#   'make': 'alfa-romero',
#   'normalized-losses': nan,
#   'num-of-cylinders': 'four',
#   'num-of-doors': 'two',
#   'peak-rpm': 5000.0,
#   'price': 13495.0,
#   'stroke': 2.68,
#   'symboling': 3,
#   'wheel-base': 88.6,
#   'width': 64.1},
#  {'aspiration': 'std',
#   'body-style': 'convertible',
#   'bore': 3.47,
#   'city-mpg': 21,
#   'compression-ratio': 9.0,
#   'curb-weight': 2548,
#   'drive-wheels': 'rwd',
#   'engine-location': 'front',
#   'engine-size': 130,
#   'engine-type': 'dohc',
#   'fuel-system': 'mpfi',
#   'fuel-type': 'gas',
#   'height': 48.8,
# ...

# %%
my_dict[0]
# Out:
# {'aspiration': 'std',
#  'body-style': 'convertible',
#  'bore': 3.47,
#  'city-mpg': 21,
#  'compression-ratio': 9.0,
#  'curb-weight': 2548,
#  'drive-wheels': 'rwd',
#  'engine-location': 'front',
#  'engine-size': 130,
#  'engine-type': 'dohc',
#  'fuel-system': 'mpfi',
#  'fuel-type': 'gas',
#  'height': 48.8,
#  'highway-mpg': 27,
#  'horsepower': 111.0,
#  'length': 168.8,
#  'make': 'alfa-romero',
#  'normalized-losses': nan,
#  'num-of-cylinders': 'four',
#  'num-of-doors': 'two',
#  'peak-rpm': 5000.0,
#  'price': 13495.0,
#  'stroke': 2.68,
#  'symboling': 3,
#  'wheel-base': 88.6,
#  'width': 64.1}
